# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Q.01.Find out how many males and females participated in the test.

# %%
data=pd.read_csv("D:\python\ictak activity\StudentsPerformance.csv")

print('the number of female candidates are:')
print(list(data['gender']).count('female'))
print('the number of male candidates:')
print(list(data['gender']).count('male'))
# Out:
# the number of female candidates are:
# 518
# the number of male candidates:
# 482

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# # Q.02.What do you think about the students' parental level of education?

# %%
plt.figure(figsize = (10,10))
ax=sns.countplot(x = "parental level of education", data = data)
ax.set_title("student's parental level of education", fontsize = 20)
plt.xlabel("parental level of education",fontsize=17)
plt.ylabel("count", fontsize=17)
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# # maximum number of parents have some level of college education of unspecified type & least number of parents have a master's degree

# %% [markdown]
# # Q.03.Who scores the most on average for math, reading and writing based on Gender/Test preparation course

# %%
sns.boxplot(x='gender',y='math score',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
sns.boxplot(x='gender',y='reading score',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='reading score'>

# %%
sns.boxplot(x='gender',y='writing score',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='writing score'>

# %%
sns.boxplot(x='test preparation course',y='writing score',data=data)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='writing score'>

# %%
sns.boxplot(x='test preparation course',y='writing score',data=data)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='writing score'>

# %%
sns.boxplot(x='test preparation course',y='writing score',data=data)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='writing score'>

# %% [markdown]
# # average score  of male is higher for maths & reading, writing scores are higher for females // candidates who have completed preparation course have scored higher than those whom have not completed in all the three categories.

# %% [markdown]
# # Q.04.What do you think about the scoring variation for math, reading and writing based on ,Gender &Test preparation course

# %% [markdown]
# # math score of males stands at 70, females at 65 - reading score of females at 72.5 and tose of male at 65-writng score of female around 75 and males at 65// #test preparation completed vs not completed ranges from 85 to 65 with a 20% difference.

# %% [markdown]
# # Q.05.The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %%
plt.figure(figsize = (20,20))
ax=sns.countplot(y = "math score", data = data)
ax.set_title("math score level", fontsize = 20)
plt.ylabel("maths score",fontsize=17)
plt.xlabel("value ", fontsize=17)
plt.grid()

# %%
plt.figure(figsize=(20,20))
sns.swarmplot(x='gender',y='math score',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
sns.violinplot(x='gender',y='math score',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
plt.figure(figsize=(20,20))
sns.swarmplot(x='test preparation course',y='math score',data=data)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='math score'>

# %% [markdown]
# # full maths score achieved by 7 students ,followed by 99,98 and 96 - by 3 students resp.,97 -by 6 students,  95 -by 2 students ,94-by 7 students. top 25 scoreres include 14males and 11 females.
